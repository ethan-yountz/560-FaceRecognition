# %% [markdown]
# # Learning Rate 0.01
# This modification tries a learning rate of 0.01.

# %% [markdown]
# # Settings

# %%
DRIVE_ROOT_DIR = "/content/drive/MyDrive/Education/UNC\\ Chapel\\ Hill/COMP560\\ FP"
SAVE_DIR = f"{DRIVE_ROOT_DIR}/lr_0_01_saves"
GIT_BRANCH = "adventure-luca"

training_args = f"""
--save_dir {SAVE_DIR}/
--lr 0.01
""".replace("\n", " ")

prediction_args = f"""
--predict
--checkpoint {SAVE_DIR}/best_model.pth
--dataset_root datasets/dataset_a
--output predictions/dataset_a.csv
""".replace("\n", " ")

shared_args = f"""
--batch_size 256
--num_workers 48
--device cuda
""".replace("\n", " ")

evaluation_args = f"""
--student_id 730665722
--prediction predictions/dataset_a.csv
--datasets dataset_a
""".replace("\n", " ")

# %% [markdown]
# # Runtime Environment Setup

# %%
# !git clone https://github.com/ethan-yountz/560-FaceRecognition
# Out:
# Cloning into '560-FaceRecognition'...
# remote: Enumerating objects: 143, done.
# remote: Counting objects: 100% (143/143), done.
# remote: Compressing objects: 100% (96/96), done.
# remote: Total 143 (delta 64), reused 120 (delta 41), pack-reused 0 (from 0)
# Receiving objects: 100% (143/143), 358.59 KiB | 4.72 MiB/s, done.
# Resolving deltas: 100% (64/64), done.

# %%
import os
os.chdir("560-FaceRecognition/project-fr")

# %%
# !git checkout {GIT_BRANCH}
# Out:
# Branch 'adventure-luca' set up to track remote branch 'adventure-luca' from 'origin'.
# Switched to a new branch 'adventure-luca'

# %%
# !pwd
# !ls
# Out:
# /content/560-FaceRecognition/project-fr
# evaluate.py  models  README.md	train_example.py

# %%
# !tar -xf {DRIVE_ROOT_DIR}/datasets.tar.gz
# Out:
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# tar: Ignoring unknown extended header keyword 'SCHILY.fflags'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.FinderInfo'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'

# %%
# %%bash
# cd datasets/dataset_a/
# tar -xf images.tar.gz

# %%
# !mkdir {SAVE_DIR}/
assert _exit_code == 0, "Saves directory must not exist"

# %%
# !ln -s {SAVE_DIR}/

# %% [markdown]
# # Train Model

# %%
cmd = f"python train_example.py {training_args} {shared_args}"
print(cmd)
# Out:
# python train_example.py  --save_dir /content/drive/MyDrive/Education/UNC\ Chapel\ Hill/COMP560\ FP/lr_0_01_saves/ --lr 0.01   --batch_size 256 --num_workers 48 --device cuda

# %%
# !{cmd}
# Out:
# Training set: 227630 images, 12115 identities
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100% 97.8M/97.8M [00:00<00:00, 191MB/s]
# Epoch 1/20: 100% 889/889 [00:56<00:00, 15.63it/s, loss=16.0233, lr=0.005000]
# Epoch 1: avg_loss=18.5538
#   Saved best model (loss=18.5538)
# Epoch 2/20: 100% 889/889 [00:54<00:00, 16.20it/s, loss=11.3407, lr=0.010000]
# Epoch 2: avg_loss=13.4936
#   Saved best model (loss=13.4936)
# Epoch 3/20: 100% 889/889 [00:54<00:00, 16.17it/s, loss=9.6490, lr=0.009924]
# Epoch 3: avg_loss=10.1417
#   Saved best model (loss=10.1417)
# Epoch 4/20: 100% 889/889 [00:54<00:00, 16.20it/s, loss=9.0107, lr=0.009698]
# Epoch 4: avg_loss=8.8179
#   Saved best model (loss=8.8179)
# Epoch 5/20: 100% 889/889 [00:54<00:00, 16.19it/s, loss=8.0205, lr=0.009330]
# Epoch 5: avg_loss=8.2101
#   Saved best model (loss=8.2101)
# Epoch 6/20: 100% 889/889 [00:54<00:00, 16.22it/s, loss=7.6887, lr=0.008830]
# Epoch 6: avg_loss=7.7659
#   Saved best model (loss=7.7659)
# Epoch 7/20: 100% 889/889 [00:54<00:00, 16.17it/s, loss=7.3337, lr=0.008214]
# Epoch 7: avg_loss=7.4639
#   Saved best model (loss=7.4639)
# Epoch 8/20: 100% 889/889 [00:55<00:00, 16.16it/s, loss=7.2419, lr=0.007500]
# Epoch 8: avg_loss=7.1756
#   Saved best model (loss=7.1756)
# Epoch 9/20: 100% 889/889 [00:54<00:00, 16.17it/s, loss=6.8147, lr=0.006710]
# Epoch 9: avg_loss=6.9194
#   Saved best model (loss=6.9194)
# Epoch 10/20: 100% 889/889 [00:54<00:00, 16.18it/s, loss=6.8658, lr=0.005868]
# Epoch 10: avg_loss=6.6888
#   Saved best model (loss=6.6888)
# Epoch 11/20: 100% 889/889 [00:55<00:00, 16.16it/s, loss=6.6785, lr=0.005000]
# Epoch 11: avg_loss=6.4836
#   Saved best model (loss=6.4836)
# Epoch 12/20: 100% 889/889 [00:54<00:00, 16.18it/s, loss=6.2960, lr=0.004132]
# Epoch 12: avg_loss=6.2960
#   Saved best model (loss=6.2960)
# Epoch 13/20: 100% 889/889 [00:55<00:00, 16.16it/s, loss=6.0935, lr=0.003290]
# Epoch 13: avg_loss=6.1204
#   Saved best model (loss=6.1204)
# Epoch 14/20: 100% 889/889 [00:54<00:00, 16.21it/s, loss=6.0157, lr=0.002500]
# Epoch 14: avg_loss=5.9725
#   Saved best model (loss=5.9725)
# Epoch 15/20: 100% 889/889 [00:55<00:00, 16.14it/s, loss=5.7357, lr=0.001786]
# Epoch 15: avg_loss=5.8375
#   Saved best model (loss=5.8375)
# Epoch 16/20: 100% 889/889 [00:55<00:00, 16.15it/s, loss=5.6824, lr=0.001170]
# Epoch 16: avg_loss=5.7241
#   Saved best model (loss=5.7241)
# Epoch 17/20: 100% 889/889 [00:54<00:00, 16.17it/s, loss=5.6290, lr=0.000670]
# Epoch 17: avg_loss=5.6349
#   Saved best model (loss=5.6349)
# Epoch 18/20: 100% 889/889 [00:54<00:00, 16.16it/s, loss=5.5345, lr=0.000302]
# Epoch 18: avg_loss=5.5687
#   Saved best model (loss=5.5687)
# Epoch 19/20: 100% 889/889 [00:55<00:00, 16.16it/s, loss=5.4990, lr=0.000076]
# Epoch 19: avg_loss=5.5287
#   Saved best model (loss=5.5287)
# Epoch 20/20: 100% 889/889 [00:54<00:00, 16.19it/s, loss=5.5808, lr=0.000000]
# Epoch 20: avg_loss=5.5099
#   Saved best model (loss=5.5099)
#
# Training complete. Best loss: 5.5099
# Checkpoints saved to: /content/drive/MyDrive/Education/UNC Chapel Hill/COMP560 FP/lr_0_01_saves

# %% [markdown]
# # Evaluate Model
# ## Generate Predictions

# %%
cmd = f"python train_example.py {prediction_args} {shared_args}"
print(cmd)
# Out:
# python train_example.py  --predict --checkpoint /content/drive/MyDrive/Education/UNC\ Chapel\ Hill/COMP560\ FP/lr_0_01_saves/best_model.pth --dataset_root datasets/dataset_a --output predictions/dataset_a.csv   --batch_size 256 --num_workers 48 --device cuda

# %%
# !{cmd}
# Out:
# Loaded checkpoint: /content/drive/MyDrive/Education/UNC Chapel Hill/COMP560 FP/lr_0_01_saves/best_model.pth (epoch 19)
# Images: 227630, Pairs: 8010270
# Encoding: 100% 890/890 [00:21<00:00, 40.63it/s]
# Aggregating template features...
# Computing pair scores...
# Scoring: 100% 17/17 [00:05<00:00,  3.40it/s]
# Predictions saved to: predictions/dataset_a.csv (8010270 pairs)

# %% [markdown]
# ## Evaluate

# %%
cmd = f"python evaluate.py {evaluation_args}"
print(cmd)
# Out:
# python evaluate.py  --student_id 730665722 --prediction predictions/dataset_a.csv --datasets dataset_a

# %%
# !{cmd}
# Out:
# ============================================================
# COMP560 Face Recognition Evaluation
# ============================================================
# Student ID: 730665722
# Prediction: predictions/dataset_a.csv
# Datasets: ['dataset_a']
# ============================================================
#
# ============================================================
# Evaluating on dataset_a
# ============================================================
#
# Performance Metrics (TAR@FAR):
#   TAR@FAR=1e-06: 13.97%
#   TAR@FAR=1e-05: 21.00%
#   TAR@FAR=1e-04: 35.67%
#   TAR@FAR=1e-03: 54.08%
#   TAR@FAR=1e-02: 76.60%
#   TAR@FAR=1e-01: 95.54%
#   AUC: 98.23%
#
# Submission Info:
#   num_predicted_pairs: 8010270
#   num_gt_pairs: 8010270
#   num_matched_pairs: 8010270
#   num_missing_pairs: 0
#   num_positive_pairs: 10270
#   num_negative_pairs: 8000000
# Traceback (most recent call last):
#   File "/content/560-FaceRecognition/project-fr/evaluate.py", line 213, in <module>
#     main()
#   File "/content/560-FaceRecognition/project-fr/evaluate.py", line 189, in main
#     json.dump(all_results, f, indent=2)
#   File "/usr/lib/python3.12/json/__init__.py", line 179, in dump
#     for chunk in iterable:
#                  ^^^^^^^^
#   File "/usr/lib/python3.12/json/encoder.py", line 432, in _iterencode
#     yield from _iterencode_dict(o, _current_indent_level)
#   File "/usr/lib/python3.12/json/encoder.py", line 406, in _iterencode_dict
#     yield from chunks
#   File "/usr/lib/python3.12/json/encoder.py", line 406, in _iterencode_dict
#     yield from chunks
#   File "/usr/lib/python3.12/json/encoder.py", line 406, in _iterencode_dict
#     yield from chunks
#   [Previous line repeated 1 more time]
#   File "/usr/lib/python3.12/json/encoder.py", line 439, in _iterencode
#     o = _default(o)
#         ^^^^^^^^^^^
#   File "/usr/lib/python3.12/json/encoder.py", line 180, in default
#     raise TypeError(f'Object of type {o.__class__.__name__} '
# TypeError: Object of type int64 is not JSON serializable
