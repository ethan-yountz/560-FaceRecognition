# %% [markdown]
# # Luca's Version
# My first modification is to use larger image sizes but a smaller embedding dimension

# %% [markdown]
# # Settings

# %%
SAVE_DIR = "lucas_version_1_saves"
GIT_BRANCH = "adventure-luca"

training_args = f"""
--save_dir {SAVE_DIR}/
""".replace("\n", " ")

prediction_args = f"""
--predict
--checkpoint {SAVE_DIR}/best_model.pth
--dataset_root datasets/dataset_a
--output predictions/dataset_a.csv
""".replace("\n", " ")

shared_args = f"""
--embedding_dim 256
--batch_size 256
--image_size 128
--num_workers 48
--device cuda
""".replace("\n", " ")

evaluation_args = f"""
--student_id 730665722
--prediction predictions/dataset_a.csv
--datasets dataset_a
""".replace("\n", " ")

# %% [markdown]
# # Runtime Environment Setup

# %%
# !git clone https://github.com/ethan-yountz/560-FaceRecognition
# Out:
# Cloning into '560-FaceRecognition'...
# remote: Enumerating objects: 132, done.
# remote: Counting objects: 100% (132/132), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 132 (delta 60), reused 110 (delta 38), pack-reused 0 (from 0)
# Receiving objects: 100% (132/132), 349.04 KiB | 2.46 MiB/s, done.
# Resolving deltas: 100% (60/60), done.

# %%
import os
os.chdir("560-FaceRecognition/project-fr")

# %%
# !git checkout {GIT_BRANCH}
# Out:
# Branch 'adventure-luca' set up to track remote branch 'adventure-luca' from 'origin'.
# Switched to a new branch 'adventure-luca'

# %%
# !pwd
# !ls
# Out:
# /content/560-FaceRecognition/project-fr
# evaluate.py  models  README.md	train_example.py

# %%
# !tar -xf /content/drive/MyDrive/Education/UNC\ Chapel\ Hill/COMP560\ FP/datasets.tar.gz
# Out:
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# tar: Ignoring unknown extended header keyword 'SCHILY.fflags'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.FinderInfo'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'

# %%
# %%bash
# cd datasets/dataset_a/
# tar -xf images.tar.gz

# %%
# !mkdir /content/drive/MyDrive/Education/UNC\ Chapel\ Hill/COMP560\ FP/{SAVE_DIR}/
assert _exit_code == 0, "Saves directory must not exist"

# %%
# !ln -s /content/drive/MyDrive/Education/UNC\ Chapel\ Hill/COMP560\ FP/{SAVE_DIR}/

# %% [markdown]
# # Train Model

# %%
cmd = f"python train_example.py {training_args} {shared_args}"
print(cmd)
# Out:
# python train_example.py  --save_dir lucas_version_1_saves/   --embedding_dim 256 --batch_size 256 --image_size 128 --num_workers 48 --device cuda

# %%
# !{cmd}
# Out:
# Training set: 227630 images, 12115 identities
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100% 97.8M/97.8M [00:00<00:00, 470MB/s]
# Epoch 1/20: 100% 889/889 [01:09<00:00, 12.88it/s, loss=20.4857, lr=0.000050]
# Epoch 1: avg_loss=23.1428
#   Saved best model (loss=23.1428)
# Epoch 2/20: 100% 889/889 [01:06<00:00, 13.33it/s, loss=16.6199, lr=0.000100]
# Epoch 2: avg_loss=18.8010
#   Saved best model (loss=18.8010)
# Epoch 3/20: 100% 889/889 [01:07<00:00, 13.24it/s, loss=14.8452, lr=0.000099]
# Epoch 3: avg_loss=15.8629
#   Saved best model (loss=15.8629)
# Epoch 4/20: 100% 889/889 [01:07<00:00, 13.26it/s, loss=13.8229, lr=0.000097]
# Epoch 4: avg_loss=14.0708
#   Saved best model (loss=14.0708)
# Epoch 5/20: 100% 889/889 [01:07<00:00, 13.23it/s, loss=12.1580, lr=0.000093]
# Epoch 5: avg_loss=12.5939
#   Saved best model (loss=12.5939)
# Epoch 6/20: 100% 889/889 [01:06<00:00, 13.28it/s, loss=10.8480, lr=0.000088]
# Epoch 6: avg_loss=11.3350
#   Saved best model (loss=11.3350)
# Epoch 7/20: 100% 889/889 [01:06<00:00, 13.28it/s, loss=10.2642, lr=0.000082]
# Epoch 7: avg_loss=10.3085
#   Saved best model (loss=10.3085)
# Epoch 8/20: 100% 889/889 [01:07<00:00, 13.24it/s, loss=9.4097, lr=0.000075]
# Epoch 8: avg_loss=9.5033
#   Saved best model (loss=9.5033)
# Epoch 9/20: 100% 889/889 [01:07<00:00, 13.26it/s, loss=8.8764, lr=0.000067]
# Epoch 9: avg_loss=8.8927
#   Saved best model (loss=8.8927)
# Epoch 10/20: 100% 889/889 [01:06<00:00, 13.27it/s, loss=7.9909, lr=0.000059]
# Epoch 10: avg_loss=8.4205
#   Saved best model (loss=8.4205)
# Epoch 11/20: 100% 889/889 [01:07<00:00, 13.27it/s, loss=8.1452, lr=0.000050]
# Epoch 11: avg_loss=8.0435
#   Saved best model (loss=8.0435)
# Epoch 12/20: 100% 889/889 [01:07<00:00, 13.25it/s, loss=7.5560, lr=0.000041]
# Epoch 12: avg_loss=7.7480
#   Saved best model (loss=7.7480)
# Epoch 13/20: 100% 889/889 [01:07<00:00, 13.23it/s, loss=7.2710, lr=0.000033]
# Epoch 13: avg_loss=7.5139
#   Saved best model (loss=7.5139)
# Epoch 14/20: 100% 889/889 [01:06<00:00, 13.27it/s, loss=7.1874, lr=0.000025]
# Epoch 14: avg_loss=7.3258
#   Saved best model (loss=7.3258)
# Epoch 15/20: 100% 889/889 [01:06<00:00, 13.29it/s, loss=6.8863, lr=0.000018]
# Epoch 15: avg_loss=7.1832
#   Saved best model (loss=7.1832)
# Epoch 16/20: 100% 889/889 [01:07<00:00, 13.26it/s, loss=6.9883, lr=0.000012]
# Epoch 16: avg_loss=7.0729
#   Saved best model (loss=7.0729)
# Epoch 17/20: 100% 889/889 [01:07<00:00, 13.25it/s, loss=6.8416, lr=0.000007]
# Epoch 17: avg_loss=6.9948
#   Saved best model (loss=6.9948)
# Epoch 18/20: 100% 889/889 [01:07<00:00, 13.25it/s, loss=6.7737, lr=0.000003]
# Epoch 18: avg_loss=6.9419
#   Saved best model (loss=6.9419)
# Epoch 19/20: 100% 889/889 [01:06<00:00, 13.27it/s, loss=6.7958, lr=0.000001]
# Epoch 19: avg_loss=6.9091
#   Saved best model (loss=6.9091)
# Epoch 20/20: 100% 889/889 [01:06<00:00, 13.29it/s, loss=6.9734, lr=0.000000]
# Epoch 20: avg_loss=6.8953
#   Saved best model (loss=6.8953)
#
# Training complete. Best loss: 6.8953
# Checkpoints saved to: lucas_version_1_saves

# %% [markdown]
# # Evaluate Model
# ## Generate Predictions

# %%
cmd = f"python train_example.py {prediction_args} {shared_args}"
print(cmd)
# Out:
# python train_example.py  --predict --checkpoint lucas_version_1_saves/best_model.pth --dataset_root datasets/dataset_a --output predictions/dataset_a.csv   --embedding_dim 256 --batch_size 256 --image_size 128 --num_workers 48 --device cuda

# %%
# !{cmd}
# Out:
# Loaded checkpoint: lucas_version_1_saves/best_model.pth (epoch 19)
# Images: 227630, Pairs: 8010270
# Encoding: 100% 890/890 [00:25<00:00, 34.89it/s]
# Aggregating template features...
# Computing pair scores...
# Scoring: 100% 17/17 [00:03<00:00,  5.59it/s]
# Predictions saved to: predictions/dataset_a.csv (8010270 pairs)

# %% [markdown]
# ## Evaluate

# %%
cmd = f"python evaluate.py {evaluation_args}"
print(cmd)
# Out:
# python evaluate.py  --student_id 730665722 --prediction predictions/dataset_a.csv --datasets dataset_a

# %%
# !{cmd}
# Out:
# ============================================================
# COMP560 Face Recognition Evaluation
# ============================================================
# Student ID: 730665722
# Prediction: predictions/dataset_a.csv
# Datasets: ['dataset_a']
# ============================================================
#
# ============================================================
# Evaluating on dataset_a
# ============================================================
#
# Performance Metrics (TAR@FAR):
#   TAR@FAR=1e-06: 6.64%
#   TAR@FAR=1e-05: 11.74%
#   TAR@FAR=1e-04: 20.37%
#   TAR@FAR=1e-03: 39.79%
#   TAR@FAR=1e-02: 66.54%
#   TAR@FAR=1e-01: 91.05%
#   AUC: 96.62%
#
# Submission Info:
#   num_predicted_pairs: 8010270
#   num_gt_pairs: 8010270
#   num_matched_pairs: 8010270
#   num_missing_pairs: 0
#   num_positive_pairs: 10270
#   num_negative_pairs: 8000000
# Traceback (most recent call last):
#   File "/content/560-FaceRecognition/project-fr/evaluate.py", line 213, in <module>
#     main()
#   File "/content/560-FaceRecognition/project-fr/evaluate.py", line 189, in main
#     json.dump(all_results, f, indent=2)
#   File "/usr/lib/python3.12/json/__init__.py", line 179, in dump
#     for chunk in iterable:
#                  ^^^^^^^^
#   File "/usr/lib/python3.12/json/encoder.py", line 432, in _iterencode
#     yield from _iterencode_dict(o, _current_indent_level)
#   File "/usr/lib/python3.12/json/encoder.py", line 406, in _iterencode_dict
#     yield from chunks
#   File "/usr/lib/python3.12/json/encoder.py", line 406, in _iterencode_dict
#     yield from chunks
#   File "/usr/lib/python3.12/json/encoder.py", line 406, in _iterencode_dict
#     yield from chunks
#   [Previous line repeated 1 more time]
#   File "/usr/lib/python3.12/json/encoder.py", line 439, in _iterencode
#     o = _default(o)
#         ^^^^^^^^^^^
#   File "/usr/lib/python3.12/json/encoder.py", line 180, in default
#     raise TypeError(f'Object of type {o.__class__.__name__} '
# TypeError: Object of type int64 is not JSON serializable
